# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import time
import json
import os
import csv

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()



# Twitter API Keys
consumer_key = "1FDMEahjFGKkgQbhA4aBoChbl"
consumer_secret = "ifGWFwIaLddfsOAyFpxg1VXoi7Y3O4lUpMe0ss1NPMHwwDv7qI"
access_token = "1412065645-qJM4pv2r5Xb84H2Fg2tTbzzWilCTTqSNjpQCAuz"
access_token_secret = "F8sXI3t0SOv5LcDY37zao3UpZnfUHps8aKOzpYphKicPy"



# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
search_term = "Trump"

 # "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Create new CSV
tweetingCSV = os.path.join('output','Trumpholdallthetweets.csv')

tweet_id_list = []

def EndlessTweet(tweetingCSV):
    with open(tweetingCSV, "a", newline="", encoding='utf-8') as tweetingCSV:
        csvwriter = csv.writer(tweetingCSV, delimiter=",")

        # Collect our tweets
        public_tweets = api.search(search_term, count=100)
        text = []
        full_name = []
        coordinates = []
        lat = []
        long = []


        # Loop through all tweets
        for tweet in public_tweets["statuses"]:
            
            if(tweet["id"] not in tweet_id_list):

                if (tweet["place"]):

                    if (tweet["place"]["country_code"]=="US"):


                        print("I AM HERE")
                        # Utilize JSON dumps to generate a pretty-printed json
                        # print(json.dumps(tweet, sort_keys = True, indent = 4))
                        tweet_id_list.append(tweet["id"])
                        text.append(tweet["text"])
                        #location.append(tweet["place"]["location"])
                        full_name.append(tweet["place"]["full_name"])
                        coord_storage = tweet["place"]["bounding_box"]["coordinates"][0][0]
                        coordinates.append(coord_storage)
                        lat.append(coord_storage[0])
                        long.append(coord_storage[1])

        print(lat)
        print(long)
        print(text)
        print(full_name)
        print(coordinates)


        for i in range(len(text)):
            csvwriter.writerow([lat[i], long[i], text[i], full_name[i], str(coordinates[i])])

                
                
                #with open("holdallthetweetsTrump.csv", 'w', newline="") as tweetingCSV:

    #csvwriter = csv.writer(tweetingCSV, delimiter=',')

    # Write tweet into file
    #csvwriter.writerow(tweet["text"],tweet["location"],tweet["full_name"],tweet["coordinates"][0])

# %%
while(True):
    EndlessTweet(tweetingCSV)
    time.sleep(15)
# Out:
# []
# []
# []
# []
# []
# I AM HERE
# [-86.348441]
# [39.631677]
# ['I know every since the crooked GOP been in office, like Donald Trump, the gas prices been high as hell. Thanks dumb ass Trump follower’s.']
# ['Indianapolis, IN']
# [[-86.348441, 39.631677]]
# I AM HERE
# [-122.807286]
# [45.281815]
# ["Apparently Donald Trump has slept with a lot of women. It's time women stop suggesting men are gross."]
# ['Wilsonville, OR']
# [[-122.807286, 45.281815]]
# []
# []
# []
# []
# []
# I AM HERE
# I AM HERE
# [-87.022482, -76.045233]
# [35.9945681, 40.188329]
# ['Does anyone know if Donald Trump called @GStephanopoulos to congratulate him on his amazing ratings numbers this we… https://t.co/k5Tg1poKzb', '@MrDane1982 I’m mad at Comey. He screwed Hillary out of the election &amp; allowed Trump to win with his email letter &amp;… https://t.co/FNDqfBMu1W']
# ['Nashville, TN', 'Bowmansville, PA']
# [[-87.022482, 35.9945681], [-76.045233, 40.188329]]
# []
# []
# []
# []
# []
# []
# []
# []
# ...
