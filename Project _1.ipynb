# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import json

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()



# Twitter API Keys
consumer_key = "sz5wb5oRXgH9bnTIZFSgvhv3b"
consumer_secret = "OrT3JaaW3JtzMeno4Q6X6bDYC5xyrAp2MERVHR6oxubdnpkVHv"
access_token = "979169790735470592-YZh7iRKW87dk7Ce7IAYlzGITHNC66hI"
access_token_secret = "jW0whjf3UGwf6BuOnOdmwLFB7BCrOJjI2WdI0srIoeRKg"


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
search_term = "coffee"

 # "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

    
public_tweets = api.search(search_term, count=100)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    if (tweet["place"]):
        if (tweet["place"]["country_code"]=="US"):
            print("I AM HERE")
    # Utilize JSON dumps to generate a pretty-printed json
            print(json.dumps(tweet, sort_keys = True, indent = 4))
# Out:
# I AM HERE
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Apr 10 04:40:08 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 2437472689,
#                 "id_str": "2437472689",
#                 "indices": [
#                     0,
#                     12
#                 ],
#                 "name": "\ud83d\udc94",
#                 "screen_name": "alyssakeiko"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 983565267715444736,
#     "id_str": "983565267715444736",
#     "in_reply_to_screen_name": "alyssakeiko",
#     "in_reply_to_status_id": 983564472093675520,
#     "in_reply_to_status_id_str": "983564472093675520",
#     "in_reply_to_user_id": 2437472689,
#     "in_reply_to_user_id_str": "2437472689",
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         -77.119401,
#                         38.801826
#                     ],
#                     [
#                         -76.909396,
#                         38.801826
#                     ],
#                     [
#                         -76.909396,
#                         38.9953797
#                     ],
#                     [
#                         -77.119401,
#                         38.9953797
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "contained_within": [],
#         "country": "United States",
#         "country_code": "US",
#         "full_name": "Washington, DC",
#         "id": "01fbe706f872cb32",
#         "name": "Washington",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/01fbe706f872cb32.json"
#     },
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "@alyssakeiko I mean same, but it\u2019s also helped me with coffee a lot.",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Nov 07 06:55:27 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Just a barista from Cleveland. Sandwich Enthusiast. Google me you turd. Inspirational. President of #coffeetwitter he/him #gobucks",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "tinyletter.com/ditriech",
#                         "expanded_url": "http://tinyletter.com/ditriech",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/kdCPqzOTc3"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 74971,
#         "follow_request_sent": false,
#         "followers_count": 638,
#         "following": false,
#         "friends_count": 274,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 10024312,
#         "id_str": "10024312",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 28,
#         "location": "Washington, DC",
#         "name": "sprohioan",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/10024312/1460927038",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/969952006495440897/wudSLiej_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/969952006495440897/wudSLiej_normal.jpg",
#         "profile_link_color": "990000",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "ditriech",
#         "statuses_count": 79605,
#         "time_zone": "Eastern Time (US & Canada)",
#         "translator_type": "none",
#         "url": "https://t.co/kdCPqzOTc3",
#         "utc_offset": -14400,
#         "verified": false
#     }
# }
# I AM HERE
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Apr 10 04:39:25 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/9\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/983565087964360704",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/GlOumHWObr"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 983565087964360704,
#     "id_str": "983565087964360704",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         -91.218994,
#                         30.354161
#                     ],
#                     [
#                         -90.962605,
#                         30.354161
#                     ],
#                     [
#                         -90.962605,
#                         30.5640391
#                     ],
#                     [
#                         -91.218994,
#                         30.5640391
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "contained_within": [],
#         "country": "United States",
#         "country_code": "US",
#         "full_name": "Baton Rouge, LA",
#         "id": "c7ef5f3368b68777",
#         "name": "Baton Rouge",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/c7ef5f3368b68777.json"
#     },
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "i\u2019m dancing to \u2018At your best\u2019 high, in a huge t-shirt, fuzzy socks, hair down, coffee ice cream pint in hand. My wo\u2026 https://t.co/GlOumHWObr",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Sep 08 14:27:00 +0000 2015",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "\ud835\udc9f\ud835\udcc7\ud835\udcbe\ud835\udcc5\ud835\udcc5\ud835\udcbe\ud835\udcc3\u2019 \ud835\udcbe\ud835\udcc3 \ud835\udcc2\ud835\udc52\ud835\udcc1\ud835\udcb6\ud835\udcc3\ud835\udcbe\ud835\udcc3 \ud835\udcb6\ud835\udcc3\ud835\udcb9 \ud835\udcbd\ud835\udc5c\ud835\udcc3\ud835\udc52\ud835\udcce \u2655 \u2800\u2800\u2800 \u2800\u2800\u2800 \u2800\u2800\u2800insta: hxneydipshawty \u2573 sc: ayanakole \u2800\u2800\u2800 \u2800\u2800\u2800 \u2800\u2800\u2800 \u2800\u2800\u2800\u2800\u2800\u2800",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 2560,
#         "follow_request_sent": false,
#         "followers_count": 730,
#         "following": false,
#         "friends_count": 360,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 3493896853,
#         "id_str": "3493896853",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 2,
#         "location": "",
#         "name": "whitley gilbert",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/3493896853/1522280127",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/971107069515452417/vBzP7BYO_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/971107069515452417/vBzP7BYO_normal.jpg",
#         "profile_link_color": "F58EA8",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "protected": false,
#         "screen_name": "hxneydipshawty",
#         "statuses_count": 2617,
#         "time_zone": "Pacific Time (US & Canada)",
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": -25200,
#         "verified": false
#     }
# }
# I AM HERE
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Apr 10 04:39:23 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/9\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/983565081345576960",
#                 "indices": [
#                     116,
#                     139
#                 ],
#                 "url": "https://t.co/j9gmB8kUQO"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 34040661,
#                 "id_str": "34040661",
#                 "indices": [
#                     0,
#                     12
#                 ],
#                 "name": "Sofia Levin \ud83c\uddf5\ud83c\uddf9",
#                 "screen_name": "sofiaflevin"
#             },
#             {
#                 "id": 10125612,
#                 "id_str": "10125612",
#                 "indices": [
#                     13,
#                     22
#                 ],
#                 "name": "Patrick Perini",
#                 "screen_name": "pcperini"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 983565081345576960,
#     "id_str": "983565081345576960",
#     "in_reply_to_screen_name": "sofiaflevin",
#     "in_reply_to_status_id": 983564782472065024,
#     "in_reply_to_status_id_str": "983564782472065024",
#     "in_reply_to_user_id": 34040661,
#     "in_reply_to_user_id_str": "34040661",
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": {
#         "attributes": {},
#         "bounding_box": {
#             "coordinates": [
#                 [
#                     [
#                         -120.71213,
#                         35.235477
#                     ],
#                     [
#                         -120.6177997,
#                         35.235477
#                     ],
#                     [
#                         -120.6177997,
#                         35.314141
#                     ],
#                     [
#                         -120.71213,
#                         35.314141
#                     ]
#                 ]
#             ],
#             "type": "Polygon"
#         },
#         "contained_within": [],
#         "country": "United States",
#         "country_code": "US",
#         "full_name": "San Luis Obispo, CA",
#         "id": "057f8a6fa3c286f9",
#         "name": "San Luis Obispo",
#         "place_type": "city",
#         "url": "https://api.twitter.com/1.1/geo/id/057f8a6fa3c286f9.json"
#     },
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://tapbots.com/tweetbot\" rel=\"nofollow\">Tweetbot for i\u039fS</a>",
#     "text": "@sofiaflevin @pcperini Socially engineer my way onto the couch of the new friend I made in the coffee shop. Ok I\u2019m\u2026 https://t.co/j9gmB8kUQO",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Dec 17 17:40:35 +0000 2011",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Problem solver, engineer. Working hard, playing harder, learning hardest. iOS developer traveling the world. Attempting to mature quickly. Open mind, open DMs.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "giladronat.com",
#                         "expanded_url": "http://giladronat.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/M8X2V5S9Ls"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 56882,
#         "follow_request_sent": false,
#         "followers_count": 2153,
#         "following": false,
#         "friends_count": 552,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 439356927,
#         "id_str": "439356927",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 133,
#         "location": "@GiladTravels @GiladPlays @GiladComplains",
#         "name": "Gilad Ronat",
#         "notifications": false,
#         "profile_background_color": "022330",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/696129207/d5f6e38dc9751a48f095b169ce7a29a9.png",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/696129207/d5f6e38dc9751a48f095b169ce7a29a9.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/439356927/1454880993",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/797228134512803840/t0hEWCBo_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/797228134512803840/t0hEWCBo_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "C0DFEC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "giladronat",
#         "statuses_count": 14566,
#         "time_zone": "Pacific Time (US & Canada)",
#         "translator_type": "none",
#         "url": "https://t.co/M8X2V5S9Ls",
#         "utc_offset": -25200,
#         "verified": false
#     }
# }
