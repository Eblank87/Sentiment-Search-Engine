# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import time
import json
import os
import csv

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()



# Twitter API Keys
consumer_key = "1FDMEahjFGKkgQbhA4aBoChbl"
consumer_secret = "ifGWFwIaLddfsOAyFpxg1VXoi7Y3O4lUpMe0ss1NPMHwwDv7qI"
access_token = "1412065645-qJM4pv2r5Xb84H2Fg2tTbzzWilCTTqSNjpQCAuz"
access_token_secret = "F8sXI3t0SOv5LcDY37zao3UpZnfUHps8aKOzpYphKicPy"



# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
search_term = "Trump"

 # "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Create new CSV
tweetingCSV = os.path.join('output','Trumpholdallthetweets.csv')

tweet_id_list = []

def EndlessTweet(tweetingCSV):
    with open(tweetingCSV, "a", newline="", encoding='utf-8') as tweetingCSV:
        csvwriter = csv.writer(tweetingCSV, delimiter=",")

        # Collect our tweets
        public_tweets = api.search(search_term, count=100)
        text = []
        full_name = []
        coordinates = []
        lat = []
        long = []


        # Loop through all tweets
        for tweet in public_tweets["statuses"]:
            
            if(tweet["id"] not in tweet_id_list):

                if (tweet["place"]):

                    if (tweet["place"]["country_code"]=="US"):


                        print("I AM HERE")
                        # Utilize JSON dumps to generate a pretty-printed json
                        # print(json.dumps(tweet, sort_keys = True, indent = 4))
                        tweet_id_list.append(tweet["id"])
                        text.append(tweet["text"])
                        #location.append(tweet["place"]["location"])
                        full_name.append(tweet["place"]["full_name"])
                        coord_storage = tweet["place"]["bounding_box"]["coordinates"][0][0]
                        coordinates.append(coord_storage)
                        lat.append(coord_storage[0])
                        long.append(coord_storage[1])

        print(lat)
        print(long)
        print(text)
        print(full_name)
        print(coordinates)


        for i in range(len(text)):
            csvwriter.writerow([lat[i], long[i], text[i], full_name[i], str(coordinates[i])])

                
                
                #with open("holdallthetweetsTrump.csv", 'w', newline="") as tweetingCSV:

    #csvwriter = csv.writer(tweetingCSV, delimiter=',')

    # Write tweet into file
    #csvwriter.writerow(tweet["text"],tweet["location"],tweet["full_name"],tweet["coordinates"][0])

# %%
while(True):
    EndlessTweet(tweetingCSV)
    time.sleep(15)
# Out:
# I AM HERE
# [-84.3488546]
# [33.764565]
# ['We finna go into war but y’all want trump (the same person y’all compared to Hitler and the devil for months) to ta… https://t.co/BmyetLdY7z']
# ['Druid Hills, GA']
# [[-84.3488546, 33.764565]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# I AM HERE
# [-118.4484512]
# [33.976882]
# ["@nachosarah I noticed trump's bright red crotch-length one early on. 'Nuff said."]
# ['Culver City, CA']
# [[-118.4484512, 33.976882]]
# I AM HERE
# [-94.258061]
# [30.200365]
# ['No... its BS for Anyone to ave this happen... Mueller must not be getting any these days at home to be looking in t… https://t.co/ZBvwP3Rc5t']
# ['Lumberton, TX']
# [[-94.258061, 30.200365]]
# []
# []
# []
# []
# []
# I AM HERE
# [-118.668404]
# [33.704538]
# ['Yo @IvankaTrump  https://t.co/gUTKwrVRZw']
# ['Los Angeles, CA']
# [[-118.668404, 33.704538]]
# []
# []
# []
# []
# []
# I AM HERE
# [-122.2107576]
# [47.300531]
# ['Wow, the comment by the commentator was rude. I blame Trump. #PGA #golf #TrumpEffect']
# ['Lea Hill, WA']
# [[-122.2107576, 47.300531]]
# []
# []
# []
# []
# []
# I AM HERE
# [-102.051769]
# [36.9931101]
# ['@LdyDrums @AuspiciousTruth And FYI, there’s no weakness in what Trump did last night, it wasn’t about regime change… https://t.co/2pU8DVr6S8']
# ['Kansas, USA']
# [[-102.051769, 36.9931101]]
# []
# []
# []
# []
# []
# I AM HERE
# [-73.838271]
# [40.984413]
# ['Trump so gangsta']
# ['Greenville, NY']
# [[-73.838271, 40.984413]]
# I AM HERE
# [-73.962582]
# [40.541722]
# ['I blame Trump https://t.co/J75M46fUMW']
# ['Queens, NY']
# [[-73.962582, 40.541722]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# I AM HERE
# [-95.686106]
# [29.5433718]
# ['@Sweetie2262 No political outrage vsTrump but contempt for his ignorant, stupid approach to foreign affairs. Those… https://t.co/zAI0mM4xIU']
# ['Sugar Land, TX']
# [[-95.686106, 29.5433718]]
# I AM HERE
# [-71.160356]
# [42.352429]
# ['@samswey “We have to be radically inclusive in our approach. There are 104 million people who support Black Lives M… https://t.co/X2EQ8ibPai']
# ['Cambridge, MA']
# [[-71.160356, 42.352429]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# I AM HERE
# [-123.204342]
# [45.209677]
# ['@ewrichards12321 @realamericadrew @realDonaldTrump Bullshit! Trump had slid thru The last 16mos of his presidency s… https://t.co/DNoq5ihGYy']
# ['U.S. Bank']
# [[-123.204342, 45.209677]]
# I AM HERE
# I AM HERE
# [-122.7900653, -82.482444]
# [45.421863, 27.668732]
# ["Maddow: Trump's personal turmoil taints U.S. military options https://t.co/nxU6S4a2TU via @msnbc", '@mike_Zollo @_SierraWhiskee I think you are correct. I think this is a way for him to keep the Deep stay occupied w… https://t.co/Qx8A2sfG9E']
# ['Portland, OR', 'Ruskin, FL']
# [[-122.7900653, 45.421863], [-82.482444, 27.668732]]
# I AM HERE
# [-75.091333]
# [38.32431]
# ['@TeaPainUSA By Trump himself']
# ['Ocean City, MD']
# [[-75.091333, 38.32431]]
# I AM HERE
# [-82.482444]
# [27.668732]
# ['@PrisonPlanet @PrisonPlanet  you guys should shed some light on the fact Trump bringing back the TPP']
# ['Ruskin, FL']
# [[-82.482444, 27.668732]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# I AM HERE
# [-84.3219475]
# [33.752879]
# ["@pollsofpolitics @realDonaldTrump if he didn't notify Russia and Syria it would have been okay by me.   the only th… https://t.co/V3uVtNtYwu"]
# ['North Carolina, USA']
# [[-84.3219475, 33.752879]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
