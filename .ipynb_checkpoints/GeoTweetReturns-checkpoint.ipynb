# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import time
import json
import os
import csv

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()



# Twitter API Keys
consumer_key = "j6UMJ9RL1s6IzP9bMuDF7aqs2"
consumer_secret = "A3oP0clXf60RzFHu9SkDtzzWRKr35sxZpKhP5RgM0CbAkwlXPa"
access_token = "979169660833710080-WiJS6293MQ0ejXeWjNaawSofVNskv53"
access_token_secret = "NIs5dvQRRXSLizsRrx4j6ATJX1JISdPudkXxYqBlpZ2dC"


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
search_term = "beyonce"

 # "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Create new CSV
tweetingCSV = os.path.join('output','holdallthetweets.csv')

tweet_id_list = []

def EndlessTweet(tweetingCSV):
    with open(tweetingCSV, "a", newline="",encoding="utf-8") as tweetingCSV:
        csvwriter = csv.writer(tweetingCSV, delimiter=",")

        # Collect our tweets
        public_tweets = api.search(search_term, count=100)
        text = []
        full_name = []
        coordinates = []
        lat = []
        long = []


        # Loop through all tweets
        for tweet in public_tweets["statuses"]:
            
            if(tweet["id"] not in tweet_id_list):

                if (tweet["place"]):

                    if (tweet["place"]["country_code"]=="US"):


                        print("I AM HERE")
                        # Utilize JSON dumps to generate a pretty-printed json
                        # print(json.dumps(tweet, sort_keys = True, indent = 4))
                        tweet_id_list.append(tweet["id"])
                        text.append(tweet["text"])
                        #location.append(tweet["place"]["location"])
                        full_name.append(tweet["place"]["full_name"])
                        coord_storage = tweet["place"]["bounding_box"]["coordinates"][0][0]
                        coordinates.append(coord_storage)
                        lat.append(coord_storage[0])
                        long.append(coord_storage[1])

        print(lat)
        print(long)
        print(text)
        print(full_name)
        print(coordinates)


        for i in range(len(text)):
            csvwriter.writerow([lat[i], long[i], text[i], full_name[i], str(coordinates[i])])

                
                
                #with open("holdallthetweets.csv", 'w', newline="") as tweetingCSV:

    #csvwriter = csv.writer(tweetingCSV, delimiter=',')

    # Write tweet into file
    #csvwriter.writerow(tweet["text"],tweet["location"],tweet["full_name"],tweet["coordinates"][0])

# %%
while(True):
    EndlessTweet(tweetingCSV)
    time.sleep(15)
# Out:
# I AM HERE
# [-105.109815]
# [39.614151]
# ['@NachoMagic I actually like a hawaiian pizza as a changeup pitch, but give me New York genuine pizza.']
# ['Denver, CO']
# [[-105.109815, 39.614151]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e38f0a86a926> in <module>()
#       1 while(True):
#       2     EndlessTweet(tweetingCSV)
# ----> 3     time.sleep(15)
#
# KeyboardInterrupt:
