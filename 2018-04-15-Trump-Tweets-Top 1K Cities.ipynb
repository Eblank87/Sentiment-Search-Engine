# %%
# 1.Youll have to install plot.ly for the map:    pip install plotly
# 2.Add your Twitter keys
# 3.Download the JSON file and put it in the same directory as this notebook https://gist.github.com/Miserlou/c5cd8364bf9b2420bb29   shoutout to this human for making the cities json file
# 4.Make your output directory for the CSV
# 5.Change jsonlen to the number of cities that you want to do, full list is 1000 test it with five first
# 6.Change search_term to your search term 
# 7. Run the code. should take about 6 hours. Nothing will show up in the CSV file till it's done. just let it do its thing
# 7. In next cell change the csv file to your output file for pandas
# 8. In the plotly cell just change the title of the map. there should be a new window that opens with the map. 
# 9. In the top righthand corner of the windoe there is a button to download it as a PNG. 
# 10. Profit.


import tweepy
import json
import csv
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


# Twitter API Keys
consumer_key = "1FDMEahjFGKkgQbhA4aBoChbl"
consumer_secret = "ifGWFwIaLddfsOAyFpxg1VXoi7Y3O4lUpMe0ss1NPMHwwDv7qI"
access_token = "1412065645-qJM4pv2r5Xb84H2Fg2tTbzzWilCTTqSNjpQCAuz"
access_token_secret = "F8sXI3t0SOv5LcDY37zao3UpZnfUHps8aKOzpYphKicPy"


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# Open/create a file to append data to
csvFile = open('Trump_Justins_Way.csv', 'w', encoding='utf-8')  #make 'a' to addend   put your output file here

cities = json.load(open('cities.json'))  #Load the cities.json file here
citylist = []
latlong = []
i = 0
distance = '20mi'
jsonlen = 1000             #change this number to count of cities in the full list are for the full list

while i < jsonlen:       
    city = cities[i]['city']
    citylist.append(city)
    
    lat = cities[i]['latitude']
    long = cities[i]['longitude']
    state = cities[i]['state']
    geocode = (str(lat) + "," + str(long) + "," + str(distance)) #do not fucking put spaces in this shit. it will not fucking work. 
    latlong.append(geocode)
    i += 1
    
city_dict = dict(zip(citylist, latlong))  
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['location', 'lat', 'long', 'tweet created at time', 'tweet text', 'tweet sentiment','tweet.user.geo_enabled'])

c = 0
search_term = ['Trump']       #put your search term here
for key, value in city_dict.items():
    testlat = value
    t = 0
    c+=1
    print(f'{key} is {c} out of {jsonlen} cities')
    for tweet in tweepy.Cursor(api.search,
                               q = search_term,
                               geocode=str(testlat),
                               #count=100,
                               lang = "en").items(100):
        
        if not tweet.retweeted and 'RT @' not in tweet.text:
        # Write a row to the CSV file. I use encode UTF-8
            csvWriter.writerow([key, testlat[0:10], testlat[11:22], tweet.created_at, tweet.text.encode('utf-8'), analyzer.polarity_scores(tweet.text)["compound"], tweet.user.geo_enabled]) #testlat is split into lat and long
            t += 1
    print(str(t) + ' results')     
    csvWriter.writerow        
csvFile.close()

print(api.rate_limit_status()['resources']['search']['/search/tweets'])  
reset_time = api.rate_limit_status()['resources']['search']['/search/tweets']['reset']
print('reset time: ' + time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(reset_time)))
# Out:
# New York is 1 out of 1000 cities
# 5 results
# Los Angeles is 2 out of 1000 cities
# 8 results
# Chicago is 3 out of 1000 cities
# 11 results
# Houston is 4 out of 1000 cities
# 37 results
# Philadelphia is 5 out of 1000 cities
# 38 results
# Phoenix is 6 out of 1000 cities
# 13 results
# San Antonio is 7 out of 1000 cities
# 45 results
# San Diego is 8 out of 1000 cities
# 63 results
# Dallas is 9 out of 1000 cities
# 24 results
# San Jose is 10 out of 1000 cities
# 35 results
# Austin is 11 out of 1000 cities
# Rate limit reached. Sleeping for: 695
# 47 results
# Indianapolis is 12 out of 1000 cities
# 50 results
# Jacksonville is 13 out of 1000 cities
# 93 results
# San Francisco is 14 out of 1000 cities
# 21 results
# Columbus is 15 out of 1000 cities
# 87 results
# Charlotte is 16 out of 1000 cities
# 28 results
# Fort Worth is 17 out of 1000 cities
# 77 results
# Detroit is 18 out of 1000 cities
# 33 results
# El Paso is 19 out of 1000 cities
# 29 results
# Memphis is 20 out of 1000 cities
# 81 results
# Seattle is 21 out of 1000 cities
# 46 results
# Denver is 22 out of 1000 cities
# 30 results
# Washington is 23 out of 1000 cities
# 2 results
# Boston is 24 out of 1000 cities
# 18 results
# Nashville-Davidson is 25 out of 1000 cities
# 74 results
# Baltimore is 26 out of 1000 cities
# 76 results
# Oklahoma City is 27 out of 1000 cities
# 71 results
# Louisville/Jefferson County is 28 out of 1000 cities
# 3 results
# Portland is 29 out of 1000 cities
# 46 results
# Las Vegas is 30 out of 1000 cities
# 46 results
# Milwaukee is 31 out of 1000 cities
# 38 results
# Albuquerque is 32 out of 1000 cities
# 52 results
# Tucson is 33 out of 1000 cities
# 79 results
# Fresno is 34 out of 1000 cities
# 19 results
# Sacramento is 35 out of 1000 cities
# 52 results
# Long Beach is 36 out of 1000 cities
# Rate limit reached. Sleeping for: 864
# 10 results
# Kansas City is 37 out of 1000 cities
# 69 results
# Mesa is 38 out of 1000 cities
# 7 results
# Virginia Beach is 39 out of 1000 cities
# 71 results
# Atlanta is 40 out of 1000 cities
# 31 results
# Colorado Springs is 41 out of 1000 cities
# 95 results
# Omaha is 42 out of 1000 cities
# 56 results
# Raleigh is 43 out of 1000 cities
# 47 results
# Miami is 44 out of 1000 cities
# 19 results
# Oakland is 45 out of 1000 cities
# 15 results
# Minneapolis is 46 out of 1000 cities
# 8 results
# Tulsa is 47 out of 1000 cities
# 66 results
# Cleveland is 48 out of 1000 cities
# 81 results
# Wichita is 49 out of 1000 cities
# 79 results
# Arlington is 50 out of 1000 cities
# 32 results
# New Orleans is 51 out of 1000 cities
# 15 results
# Bakersfield is 52 out of 1000 cities
# 94 results
# Tampa is 53 out of 1000 cities
# 44 results
# Honolulu is 54 out of 1000 cities
# 69 results
# Aurora is 55 out of 1000 cities
# 69 results
# Anaheim is 56 out of 1000 cities
# 35 results
# Santa Ana is 57 out of 1000 cities
# 26 results
# St. Louis is 58 out of 1000 cities
# 12 results
# Riverside is 59 out of 1000 cities
# Rate limit reached. Sleeping for: 865
# 72 results
# Corpus Christi is 60 out of 1000 cities
# 81 results
# Lexington-Fayette is 61 out of 1000 cities
# 49 results
# Pittsburgh is 62 out of 1000 cities
# 12 results
# Anchorage is 63 out of 1000 cities
# 44 results
# Stockton is 64 out of 1000 cities
# 92 results
# Cincinnati is 65 out of 1000 cities
# 11 results
# St. Paul is 66 out of 1000 cities
# 16 results
# Toledo is 67 out of 1000 cities
# 56 results
# Greensboro is 68 out of 1000 cities
# 67 results
# Newark is 69 out of 1000 cities
# 38 results
# Plano is 70 out of 1000 cities
# 27 results
# Henderson is 71 out of 1000 cities
# 44 results
# Lincoln is 72 out of 1000 cities
# 34 results
# Buffalo is 73 out of 1000 cities
# 58 results
# Jersey City is 74 out of 1000 cities
# 8 results
# Chula Vista is 75 out of 1000 cities
# 60 results
# Fort Wayne is 76 out of 1000 cities
# 79 results
# Orlando is 77 out of 1000 cities
# 11 results
# St. Petersburg is 78 out of 1000 cities
# 46 results
# Chandler is 79 out of 1000 cities
# 6 results
# Laredo is 80 out of 1000 cities
# 91 results
# Norfolk is 81 out of 1000 cities
# 73 results
# Durham is 82 out of 1000 cities
# 50 results
# Madison is 83 out of 1000 cities
# 78 results
# Lubbock is 84 out of 1000 cities
# Rate limit reached. Sleeping for: 865
# 85 results
# Irvine is 85 out of 1000 cities
# 29 results
# Winston-Salem is 86 out of 1000 cities
# 44 results
# Glendale is 87 out of 1000 cities
# 5 results
# Garland is 88 out of 1000 cities
# 35 results
# Hialeah is 89 out of 1000 cities
# 43 results
# Reno is 90 out of 1000 cities
# 77 results
# Chesapeake is 91 out of 1000 cities
# 76 results
# Gilbert is 92 out of 1000 cities
# 12 results
# Baton Rouge is 93 out of 1000 cities
# 51 results
# Irving is 94 out of 1000 cities
# 39 results
# Scottsdale is 95 out of 1000 cities
# 13 results
# North Las Vegas is 96 out of 1000 cities
# 50 results
# Fremont is 97 out of 1000 cities
# 34 results
# Boise City is 98 out of 1000 cities
# 77 results
# Richmond is 99 out of 1000 cities
# 26 results
# San Bernardino is 100 out of 1000 cities
# 69 results
# Birmingham is 101 out of 1000 cities
# 54 results
# Spokane is 102 out of 1000 cities
# 62 results
# Rochester is 103 out of 1000 cities
# 45 results
# Des Moines is 104 out of 1000 cities
# 64 results
# Modesto is 105 out of 1000 cities
# 50 results
# Fayetteville is 106 out of 1000 cities
# 79 results
# Tacoma is 107 out of 1000 cities
# 77 results
# Oxnard is 108 out of 1000 cities
# 66 results
# Fontana is 109 out of 1000 cities
# Rate limit reached. Sleeping for: 864
# 71 results
# Montgomery is 110 out of 1000 cities
# 56 results
# Moreno Valley is 111 out of 1000 cities
# 68 results
# Shreveport is 112 out of 1000 cities
# 82 results
# Yonkers is 113 out of 1000 cities
# 8 results
# Akron is 114 out of 1000 cities
# 80 results
# Huntington Beach is 115 out of 1000 cities
# 40 results
# Little Rock is 116 out of 1000 cities
# 73 results
# Augusta-Richmond County is 117 out of 1000 cities
# 51 results
# Amarillo is 118 out of 1000 cities
# 88 results
# Mobile is 119 out of 1000 cities
# 31 results
# Grand Rapids is 120 out of 1000 cities
# 9 results
# Salt Lake City is 121 out of 1000 cities
# 55 results
# Tallahassee is 122 out of 1000 cities
# 79 results
# Huntsville is 123 out of 1000 cities
# 48 results
# Grand Prairie is 124 out of 1000 cities
# 40 results
# Knoxville is 125 out of 1000 cities
# 83 results
# Worcester is 126 out of 1000 cities
# 91 results
# Newport News is 127 out of 1000 cities
# 74 results
# Brownsville is 128 out of 1000 cities
# 92 results
# Overland Park is 129 out of 1000 cities
# 67 results
# Santa Clarita is 130 out of 1000 cities
# 3 results
# Providence is 131 out of 1000 cities
# 86 results
# Garden Grove is 132 out of 1000 cities
# 51 results
# Chattanooga is 133 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 83 results
# Oceanside is 134 out of 1000 cities
# 72 results
# Jackson is 135 out of 1000 cities
# 89 results
# Fort Lauderdale is 136 out of 1000 cities
# 36 results
# Santa Rosa is 137 out of 1000 cities
# 83 results
# Rancho Cucamonga is 138 out of 1000 cities
# 78 results
# Port St. Lucie is 139 out of 1000 cities
# 4 results
# Tempe is 140 out of 1000 cities
# 16 results
# Ontario is 141 out of 1000 cities
# 30 results
# Vancouver is 142 out of 1000 cities
# 21 results
# Cape Coral is 143 out of 1000 cities
# 0 results
# Sioux Falls is 144 out of 1000 cities
# 71 results
# Springfield is 145 out of 1000 cities
# 74 results
# Peoria is 146 out of 1000 cities
# 16 results
# Pembroke Pines is 147 out of 1000 cities
# 2 results
# Elk Grove is 148 out of 1000 cities
# 50 results
# Salem is 149 out of 1000 cities
# 32 results
# Lancaster is 150 out of 1000 cities
# 30 results
# Corona is 151 out of 1000 cities
# 41 results
# Eugene is 152 out of 1000 cities
# 54 results
# Palmdale is 153 out of 1000 cities
# 52 results
# Salinas is 154 out of 1000 cities
# 80 results
# Pasadena is 155 out of 1000 cities
# 3 results
# Fort Collins is 156 out of 1000 cities
# 67 results
# Hayward is 157 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 27 results
# Pomona is 158 out of 1000 cities
# 34 results
# Cary is 159 out of 1000 cities
# 46 results
# Rockford is 160 out of 1000 cities
# 39 results
# Alexandria is 161 out of 1000 cities
# 83 results
# Escondido is 162 out of 1000 cities
# 72 results
# McKinney is 163 out of 1000 cities
# 30 results
# Joliet is 164 out of 1000 cities
# 84 results
# Sunnyvale is 165 out of 1000 cities
# 39 results
# Torrance is 166 out of 1000 cities
# 12 results
# Bridgeport is 167 out of 1000 cities
# 17 results
# Lakewood is 168 out of 1000 cities
# 70 results
# Hollywood is 169 out of 1000 cities
# 20 results
# Paterson is 170 out of 1000 cities
# 8 results
# Naperville is 171 out of 1000 cities
# 70 results
# Syracuse is 172 out of 1000 cities
# 65 results
# Mesquite is 173 out of 1000 cities
# 32 results
# Dayton is 174 out of 1000 cities
# 77 results
# Savannah is 175 out of 1000 cities
# 78 results
# Clarksville is 176 out of 1000 cities
# 85 results
# Orange is 177 out of 1000 cities
# 54 results
# Fullerton is 178 out of 1000 cities
# 11 results
# Killeen is 179 out of 1000 cities
# 56 results
# Frisco is 180 out of 1000 cities
# Rate limit reached. Sleeping for: 862
# 32 results
# Hampton is 181 out of 1000 cities
# 64 results
# McAllen is 182 out of 1000 cities
# 81 results
# Warren is 183 out of 1000 cities
# 85 results
# Bellevue is 184 out of 1000 cities
# 57 results
# West Valley City is 185 out of 1000 cities
# 56 results
# Columbia is 186 out of 1000 cities
# 85 results
# Olathe is 187 out of 1000 cities
# 57 results
# Sterling Heights is 188 out of 1000 cities
# 42 results
# New Haven is 189 out of 1000 cities
# 17 results
# Miramar is 190 out of 1000 cities
# 4 results
# Waco is 191 out of 1000 cities
# 3 results
# Thousand Oaks is 192 out of 1000 cities
# 51 results
# Cedar Rapids is 193 out of 1000 cities
# 89 results
# Charleston is 194 out of 1000 cities
# 24 results
# Visalia is 195 out of 1000 cities
# 85 results
# Topeka is 196 out of 1000 cities
# 84 results
# Elizabeth is 197 out of 1000 cities
# 8 results
# Gainesville is 198 out of 1000 cities
# 52 results
# Thornton is 199 out of 1000 cities
# 62 results
# Roseville is 200 out of 1000 cities
# 40 results
# Carrollton is 201 out of 1000 cities
# 31 results
# Coral Springs is 202 out of 1000 cities
# 24 results
# Stamford is 203 out of 1000 cities
# 82 results
# Simi Valley is 204 out of 1000 cities
# 50 results
# Concord is 205 out of 1000 cities
# Rate limit reached. Sleeping for: 858
# 79 results
# Hartford is 206 out of 1000 cities
# 71 results
# Kent is 207 out of 1000 cities
# 51 results
# Lafayette is 208 out of 1000 cities
# 46 results
# Midland is 209 out of 1000 cities
# 90 results
# Surprise is 210 out of 1000 cities
# 14 results
# Denton is 211 out of 1000 cities
# 87 results
# Victorville is 212 out of 1000 cities
# 79 results
# Evansville is 213 out of 1000 cities
# 84 results
# Santa Clara is 214 out of 1000 cities
# 43 results
# Abilene is 215 out of 1000 cities
# 61 results
# Athens-Clarke County is 216 out of 1000 cities
# 81 results
# Vallejo is 217 out of 1000 cities
# 61 results
# Allentown is 218 out of 1000 cities
# 62 results
# Norman is 219 out of 1000 cities
# 71 results
# Beaumont is 220 out of 1000 cities
# 69 results
# Independence is 221 out of 1000 cities
# 57 results
# Murfreesboro is 222 out of 1000 cities
# 21 results
# Ann Arbor is 223 out of 1000 cities
# 22 results
# Berkeley is 224 out of 1000 cities
# 31 results
# Provo is 225 out of 1000 cities
# 87 results
# El Monte is 226 out of 1000 cities
# 4 results
# Lansing is 227 out of 1000 cities
# 73 results
# Fargo is 228 out of 1000 cities
# 70 results
# Downey is 229 out of 1000 cities
# 3 results
# Costa Mesa is 230 out of 1000 cities
# Rate limit reached. Sleeping for: 856
# 29 results
# Wilmington is 231 out of 1000 cities
# 72 results
# Arvada is 232 out of 1000 cities
# 69 results
# Inglewood is 233 out of 1000 cities
# 10 results
# Miami Gardens is 234 out of 1000 cities
# 4 results
# Carlsbad is 235 out of 1000 cities
# 72 results
# Westminster is 236 out of 1000 cities
# 40 results
# Odessa is 237 out of 1000 cities
# 14 results
# Manchester is 238 out of 1000 cities
# 83 results
# Elgin is 239 out of 1000 cities
# 63 results
# West Jordan is 240 out of 1000 cities
# 55 results
# Round Rock is 241 out of 1000 cities
# 24 results
# Clearwater is 242 out of 1000 cities
# 45 results
# Waterbury is 243 out of 1000 cities
# 9 results
# Gresham is 244 out of 1000 cities
# 29 results
# Fairfield is 245 out of 1000 cities
# 29 results
# Billings is 246 out of 1000 cities
# 57 results
# Lowell is 247 out of 1000 cities
# 55 results
# San Buenaventura (Ventura) is 248 out of 1000 cities
# 72 results
# Pueblo is 249 out of 1000 cities
# 80 results
# High Point is 250 out of 1000 cities
# 31 results
# West Covina is 251 out of 1000 cities
# 7 results
# Murrieta is 252 out of 1000 cities
# 14 results
# Cambridge is 253 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 41 results
# Antioch is 254 out of 1000 cities
# 87 results
# Temecula is 255 out of 1000 cities
# 86 results
# Norwalk is 256 out of 1000 cities
# 70 results
# Centennial is 257 out of 1000 cities
# 63 results
# Everett is 258 out of 1000 cities
# 25 results
# Palm Bay is 259 out of 1000 cities
# 57 results
# Wichita Falls is 260 out of 1000 cities
# 54 results
# Green Bay is 261 out of 1000 cities
# 55 results
# Daly City is 262 out of 1000 cities
# 30 results
# Burbank is 263 out of 1000 cities
# 4 results
# Richardson is 264 out of 1000 cities
# 30 results
# Pompano Beach is 265 out of 1000 cities
# 29 results
# North Charleston is 266 out of 1000 cities
# 59 results
# Broken Arrow is 267 out of 1000 cities
# 66 results
# Boulder is 268 out of 1000 cities
# 60 results
# West Palm Beach is 269 out of 1000 cities
# 6 results
# Santa Maria is 270 out of 1000 cities
# 92 results
# El Cajon is 271 out of 1000 cities
# 79 results
# Davenport is 272 out of 1000 cities
# 96 results
# Rialto is 273 out of 1000 cities
# 76 results
# Las Cruces is 274 out of 1000 cities
# 44 results
# San Mateo is 275 out of 1000 cities
# 34 results
# Lewisville is 276 out of 1000 cities
# 31 results
# South Bend is 277 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 82 results
# Lakeland is 278 out of 1000 cities
# 53 results
# Erie is 279 out of 1000 cities
# 51 results
# Tyler is 280 out of 1000 cities
# 16 results
# Pearland is 281 out of 1000 cities
# 34 results
# College Station is 282 out of 1000 cities
# 74 results
# Kenosha is 283 out of 1000 cities
# 57 results
# Sandy Springs is 284 out of 1000 cities
# 8 results
# Clovis is 285 out of 1000 cities
# 39 results
# Flint is 286 out of 1000 cities
# 86 results
# Roanoke is 287 out of 1000 cities
# 49 results
# Albany is 288 out of 1000 cities
# 80 results
# Jurupa Valley is 289 out of 1000 cities
# 82 results
# Compton is 290 out of 1000 cities
# 11 results
# San Angelo is 291 out of 1000 cities
# 82 results
# Hillsboro is 292 out of 1000 cities
# 20 results
# Lawton is 293 out of 1000 cities
# 98 results
# Renton is 294 out of 1000 cities
# 42 results
# Vista is 295 out of 1000 cities
# 72 results
# Davie is 296 out of 1000 cities
# 40 results
# Greeley is 297 out of 1000 cities
# 66 results
# Mission Viejo is 298 out of 1000 cities
# 30 results
# Portsmouth is 299 out of 1000 cities
# 75 results
# Dearborn is 300 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 43 results
# South Gate is 301 out of 1000 cities
# 8 results
# Tuscaloosa is 302 out of 1000 cities
# 59 results
# Livonia is 303 out of 1000 cities
# 46 results
# New Bedford is 304 out of 1000 cities
# 59 results
# Vacaville is 305 out of 1000 cities
# 86 results
# Brockton is 306 out of 1000 cities
# 21 results
# Roswell is 307 out of 1000 cities
# 52 results
# Beaverton is 308 out of 1000 cities
# 33 results
# Quincy is 309 out of 1000 cities
# 48 results
# Sparks is 310 out of 1000 cities
# 71 results
# Yakima is 311 out of 1000 cities
# 62 results
# Lee's Summit is 312 out of 1000 cities
# 46 results
# Federal Way is 313 out of 1000 cities
# 44 results
# Carson is 314 out of 1000 cities
# 10 results
# Santa Monica is 315 out of 1000 cities
# 8 results
# Hesperia is 316 out of 1000 cities
# 82 results
# Allen is 317 out of 1000 cities
# 42 results
# Rio Rancho is 318 out of 1000 cities
# 46 results
# Yuma is 319 out of 1000 cities
# 90 results
# Orem is 320 out of 1000 cities
# 84 results
# Lynn is 321 out of 1000 cities
# 19 results
# Redding is 322 out of 1000 cities
# 42 results
# Spokane Valley is 323 out of 1000 cities
# 66 results
# Miami Beach is 324 out of 1000 cities
# 1 results
# League City is 325 out of 1000 cities
# Rate limit reached. Sleeping for: 862
# 74 results
# Lawrence is 326 out of 1000 cities
# 41 results
# Santa Barbara is 327 out of 1000 cities
# 55 results
# Plantation is 328 out of 1000 cities
# 20 results
# Sandy is 329 out of 1000 cities
# 31 results
# Sunrise is 330 out of 1000 cities
# 20 results
# Macon is 331 out of 1000 cities
# 96 results
# Longmont is 332 out of 1000 cities
# 66 results
# Boca Raton is 333 out of 1000 cities
# 31 results
# San Marcos is 334 out of 1000 cities
# 8 results
# Greenville is 335 out of 1000 cities
# 77 results
# Waukegan is 336 out of 1000 cities
# 65 results
# Fall River is 337 out of 1000 cities
# 52 results
# Chico is 338 out of 1000 cities
# 79 results
# Newton is 339 out of 1000 cities
# 20 results
# San Leandro is 340 out of 1000 cities
# 31 results
# Reading is 341 out of 1000 cities
# 86 results
# Fort Smith is 342 out of 1000 cities
# 78 results
# Newport Beach is 343 out of 1000 cities
# 23 results
# Asheville is 344 out of 1000 cities
# 76 results
# Nashua is 345 out of 1000 cities
# 50 results
# Edmond is 346 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 80 results
# Whittier is 347 out of 1000 cities
# 9 results
# Nampa is 348 out of 1000 cities
# 79 results
# Bloomington is 349 out of 1000 cities
# 27 results
# Deltona is 350 out of 1000 cities
# 73 results
# Hawthorne is 351 out of 1000 cities
# 8 results
# Duluth is 352 out of 1000 cities
# 83 results
# Carmel is 353 out of 1000 cities
# 44 results
# Suffolk is 354 out of 1000 cities
# 63 results
# Clifton is 355 out of 1000 cities
# 3 results
# Citrus Heights is 356 out of 1000 cities
# 51 results
# Livermore is 357 out of 1000 cities
# 2 results
# Tracy is 358 out of 1000 cities
# 95 results
# Alhambra is 359 out of 1000 cities
# 7 results
# Kirkland is 360 out of 1000 cities
# 49 results
# Trenton is 361 out of 1000 cities
# 34 results
# Ogden is 362 out of 1000 cities
# 91 results
# Hoover is 363 out of 1000 cities
# 53 results
# Cicero is 364 out of 1000 cities
# 12 results
# Fishers is 365 out of 1000 cities
# 44 results
# Sugar Land is 366 out of 1000 cities
# 32 results
# Danbury is 367 out of 1000 cities
# 76 results
# Meridian is 368 out of 1000 cities
# 57 results
# Indio is 369 out of 1000 cities
# 8 results
# Menifee is 370 out of 1000 cities
# 82 results
# Champaign is 371 out of 1000 cities
# 82 results
# Buena Park is 372 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 12 results
# Troy is 373 out of 1000 cities
# 57 results
# O'Fallon is 374 out of 1000 cities
# 92 results
# Johns Creek is 375 out of 1000 cities
# 87 results
# Bellingham is 376 out of 1000 cities
# 88 results
# Westland is 377 out of 1000 cities
# 39 results
# Sioux City is 378 out of 1000 cities
# 83 results
# Warwick is 379 out of 1000 cities
# 50 results
# Hemet is 380 out of 1000 cities
# 71 results
# Longview is 381 out of 1000 cities
# 34 results
# Farmington Hills is 382 out of 1000 cities
# 81 results
# Bend is 383 out of 1000 cities
# 63 results
# Merced is 384 out of 1000 cities
# 86 results
# Mission is 385 out of 1000 cities
# 81 results
# Chino is 386 out of 1000 cities
# 55 results
# Redwood City is 387 out of 1000 cities
# 51 results
# Edinburg is 388 out of 1000 cities
# 81 results
# Cranston is 389 out of 1000 cities
# 88 results
# Parma is 390 out of 1000 cities
# 73 results
# New Rochelle is 391 out of 1000 cities
# 3 results
# Lake Forest is 392 out of 1000 cities
# 18 results
# Napa is 393 out of 1000 cities
# 86 results
# Hammond is 394 out of 1000 cities
# 12 results
# Avondale is 395 out of 1000 cities
# 8 results
# Somerville is 396 out of 1000 cities
# 29 results
# Palm Coast is 397 out of 1000 cities
# 75 results
# Bryan is 398 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 75 results
# Gary is 399 out of 1000 cities
# 14 results
# Largo is 400 out of 1000 cities
# 43 results
# Brooklyn Park is 401 out of 1000 cities
# 2 results
# Tustin is 402 out of 1000 cities
# 26 results
# Racine is 403 out of 1000 cities
# 67 results
# Deerfield Beach is 404 out of 1000 cities
# 13 results
# Lynchburg is 405 out of 1000 cities
# 82 results
# Mountain View is 406 out of 1000 cities
# 51 results
# Medford is 407 out of 1000 cities
# 28 results
# Bellflower is 408 out of 1000 cities
# 13 results
# Melbourne is 409 out of 1000 cities
# 61 results
# St. Joseph is 410 out of 1000 cities
# 65 results
# Camden is 411 out of 1000 cities
# 11 results
# St. George is 412 out of 1000 cities
# 90 results
# Kennewick is 413 out of 1000 cities
# 90 results
# Baldwin Park is 414 out of 1000 cities
# 9 results
# Chino Hills is 415 out of 1000 cities
# 53 results
# Alameda is 416 out of 1000 cities
# 39 results
# Arlington Heights is 417 out of 1000 cities
# 52 results
# Scranton is 418 out of 1000 cities
# 48 results
# Evanston is 419 out of 1000 cities
# 16 results
# Kalamazoo is 420 out of 1000 cities
# 89 results
# Baytown is 421 out of 1000 cities
# 48 results
# Upland is 422 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 44 results
# Springdale is 423 out of 1000 cities
# 81 results
# Bethlehem is 424 out of 1000 cities
# 42 results
# Schaumburg is 425 out of 1000 cities
# 49 results
# Mount Pleasant is 426 out of 1000 cities
# 58 results
# Auburn is 427 out of 1000 cities
# 48 results
# Decatur is 428 out of 1000 cities
# 77 results
# San Ramon is 429 out of 1000 cities
# 11 results
# Pleasanton is 430 out of 1000 cities
# 2 results
# Wyoming is 431 out of 1000 cities
# 3 results
# Lake Charles is 432 out of 1000 cities
# 41 results
# Plymouth is 433 out of 1000 cities
# 4 results
# Bolingbrook is 434 out of 1000 cities
# 60 results
# Pharr is 435 out of 1000 cities
# 80 results
# Appleton is 436 out of 1000 cities
# 57 results
# Gastonia is 437 out of 1000 cities
# 17 results
# Folsom is 438 out of 1000 cities
# 66 results
# Southfield is 439 out of 1000 cities
# 53 results
# Rochester Hills is 440 out of 1000 cities
# 84 results
# New Britain is 441 out of 1000 cities
# 68 results
# Goodyear is 442 out of 1000 cities
# 11 results
# Canton is 443 out of 1000 cities
# 76 results
# Warner Robins is 444 out of 1000 cities
# 98 results
# Union City is 445 out of 1000 cities
# 3 results
# Perris is 446 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 77 results
# Manteca is 447 out of 1000 cities
# 55 results
# Iowa City is 448 out of 1000 cities
# 92 results
# Jonesboro is 449 out of 1000 cities
# 85 results
# Lynwood is 450 out of 1000 cities
# 5 results
# Loveland is 451 out of 1000 cities
# 78 results
# Pawtucket is 452 out of 1000 cities
# 90 results
# Boynton Beach is 453 out of 1000 cities
# 5 results
# Waukesha is 454 out of 1000 cities
# 46 results
# Gulfport is 455 out of 1000 cities
# 11 results
# Apple Valley is 456 out of 1000 cities
# 7 results
# Passaic is 457 out of 1000 cities
# 3 results
# Rapid City is 458 out of 1000 cities
# 87 results
# Layton is 459 out of 1000 cities
# 96 results
# Turlock is 460 out of 1000 cities
# 46 results
# Muncie is 461 out of 1000 cities
# 73 results
# Temple is 462 out of 1000 cities
# 59 results
# Missouri City is 463 out of 1000 cities
# 44 results
# Redlands is 464 out of 1000 cities
# 84 results
# Santa Fe is 465 out of 1000 cities
# 8 results
# Lauderhill is 466 out of 1000 cities
# 24 results
# Milpitas is 467 out of 1000 cities
# 47 results
# Palatine is 468 out of 1000 cities
# 58 results
# Missoula is 469 out of 1000 cities
# Rate limit reached. Sleeping for: 862
# 36 results
# Rock Hill is 470 out of 1000 cities
# 94 results
# Franklin is 471 out of 1000 cities
# 58 results
# Flagstaff is 472 out of 1000 cities
# 72 results
# Flower Mound is 473 out of 1000 cities
# 46 results
# Weston is 474 out of 1000 cities
# 27 results
# Waterloo is 475 out of 1000 cities
# 74 results
# Mount Vernon is 476 out of 1000 cities
# 6 results
# Fort Myers is 477 out of 1000 cities
# 1 results
# Dothan is 478 out of 1000 cities
# 87 results
# Rancho Cordova is 479 out of 1000 cities
# 59 results
# Redondo Beach is 480 out of 1000 cities
# 8 results
# Pasco is 481 out of 1000 cities
# 90 results
# St. Charles is 482 out of 1000 cities
# 6 results
# Eau Claire is 483 out of 1000 cities
# 84 results
# North Richland Hills is 484 out of 1000 cities
# 45 results
# Bismarck is 485 out of 1000 cities
# 80 results
# Yorba Linda is 486 out of 1000 cities
# 44 results
# Kenner is 487 out of 1000 cities
# 13 results
# Walnut Creek is 488 out of 1000 cities
# 31 results
# Frederick is 489 out of 1000 cities
# 77 results
# Oshkosh is 490 out of 1000 cities
# 72 results
# Pittsburg is 491 out of 1000 cities
# 79 results
# Palo Alto is 492 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 56 results
# Bossier City is 493 out of 1000 cities
# 81 results
# St. Cloud is 494 out of 1000 cities
# 89 results
# Davis is 495 out of 1000 cities
# 60 results
# South San Francisco is 496 out of 1000 cities
# 7 results
# Camarillo is 497 out of 1000 cities
# 55 results
# North Little Rock is 498 out of 1000 cities
# 75 results
# Schenectady is 499 out of 1000 cities
# 62 results
# Gaithersburg is 500 out of 1000 cities
# 2 results
# Harlingen is 501 out of 1000 cities
# 81 results
# Woodbury is 502 out of 1000 cities
# 8 results
# Eagan is 503 out of 1000 cities
# 9 results
# Yuba City is 504 out of 1000 cities
# 0 results
# Maple Grove is 505 out of 1000 cities
# 20 results
# Youngstown is 506 out of 1000 cities
# 88 results
# Skokie is 507 out of 1000 cities
# 9 results
# Kissimmee is 508 out of 1000 cities
# 4 results
# Johnson City is 509 out of 1000 cities
# 7 results
# Victoria is 510 out of 1000 cities
# 72 results
# San Clemente is 511 out of 1000 cities
# 21 results
# Bayonne is 512 out of 1000 cities
# 8 results
# Laguna Niguel is 513 out of 1000 cities
# 29 results
# East Orange is 514 out of 1000 cities
# 7 results
# Shawnee is 515 out of 1000 cities
# 55 results
# Homestead is 516 out of 1000 cities
# 0 results
# Rockville is 517 out of 1000 cities
# Rate limit reached. Sleeping for: 861
# 2 results
# Delray Beach is 518 out of 1000 cities
# 3 results
# Janesville is 519 out of 1000 cities
# 12 results
# Conway is 520 out of 1000 cities
# 52 results
# Pico Rivera is 521 out of 1000 cities
# 8 results
# Lorain is 522 out of 1000 cities
# 70 results
# Montebello is 523 out of 1000 cities
# 8 results
# Lodi is 524 out of 1000 cities
# 56 results
# New Braunfels is 525 out of 1000 cities
# 18 results
# Marysville is 526 out of 1000 cities
# 54 results
# Tamarac is 527 out of 1000 cities
# 32 results
# Madera is 528 out of 1000 cities
# 30 results
# Conroe is 529 out of 1000 cities
# 65 results
# Santa Cruz is 530 out of 1000 cities
# 46 results
# Eden Prairie is 531 out of 1000 cities
# 5 results
# Cheyenne is 532 out of 1000 cities
# 82 results
# Daytona Beach is 533 out of 1000 cities
# 70 results
# Alpharetta is 534 out of 1000 cities
# 79 results
# Hamilton is 535 out of 1000 cities
# 24 results
# Waltham is 536 out of 1000 cities
# 21 results
# Coon Rapids is 537 out of 1000 cities
# 24 results
# Haverhill is 538 out of 1000 cities
# 72 results
# Council Bluffs is 539 out of 1000 cities
# 72 results
# Taylor is 540 out of 1000 cities
# 52 results
# Utica is 541 out of 1000 cities
# 63 results
# Ames is 542 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 90 results
# La Habra is 543 out of 1000 cities
# 9 results
# Encinitas is 544 out of 1000 cities
# 65 results
# Bowling Green is 545 out of 1000 cities
# 94 results
# Burnsville is 546 out of 1000 cities
# 8 results
# West Des Moines is 547 out of 1000 cities
# 67 results
# Cedar Park is 548 out of 1000 cities
# 16 results
# Tulare is 549 out of 1000 cities
# 88 results
# Monterey Park is 550 out of 1000 cities
# 10 results
# Vineland is 551 out of 1000 cities
# 52 results
# Terre Haute is 552 out of 1000 cities
# 67 results
# North Miami is 553 out of 1000 cities
# 6 results
# Mansfield is 554 out of 1000 cities
# 92 results
# West Allis is 555 out of 1000 cities
# 6 results
# Bristol is 556 out of 1000 cities
# 65 results
# Taylorsville is 557 out of 1000 cities
# 62 results
# Malden is 558 out of 1000 cities
# 30 results
# Meriden is 559 out of 1000 cities
# 31 results
# Blaine is 560 out of 1000 cities
# 6 results
# Wellington is 561 out of 1000 cities
# 3 results
# Cupertino is 562 out of 1000 cities
# 38 results
# Rogers is 563 out of 1000 cities
# 79 results
# St. Clair Shores is 564 out of 1000 cities
# 55 results
# Gardena is 565 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 11 results
# Pontiac is 566 out of 1000 cities
# 76 results
# National City is 567 out of 1000 cities
# 53 results
# Grand Junction is 568 out of 1000 cities
# 84 results
# Rocklin is 569 out of 1000 cities
# 58 results
# Chapel Hill is 570 out of 1000 cities
# 77 results
# Casper is 571 out of 1000 cities
# 90 results
# Broomfield is 572 out of 1000 cities
# 58 results
# Petaluma is 573 out of 1000 cities
# 80 results
# South Jordan is 574 out of 1000 cities
# 58 results
# Great Falls is 575 out of 1000 cities
# 58 results
# North Port is 576 out of 1000 cities
# 77 results
# Marietta is 577 out of 1000 cities
# 33 results
# San Rafael is 578 out of 1000 cities
# 12 results
# Royal Oak is 579 out of 1000 cities
# 58 results
# Des Plaines is 580 out of 1000 cities
# 13 results
# Huntington Park is 581 out of 1000 cities
# 6 results
# La Mesa is 582 out of 1000 cities
# 54 results
# Orland Park is 583 out of 1000 cities
# 11 results
# Lakeville is 584 out of 1000 cities
# 2 results
# Owensboro is 585 out of 1000 cities
# 86 results
# Moore is 586 out of 1000 cities
# 70 results
# Jupiter is 587 out of 1000 cities
# 11 results
# Idaho Falls is 588 out of 1000 cities
# 61 results
# Dubuque is 589 out of 1000 cities
# 68 results
# Bartlett is 590 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 63 results
# Rowlett is 591 out of 1000 cities
# 27 results
# Novi is 592 out of 1000 cities
# 15 results
# White Plains is 593 out of 1000 cities
# 63 results
# Arcadia is 594 out of 1000 cities
# 9 results
# Redmond is 595 out of 1000 cities
# 62 results
# Lake Elsinore is 596 out of 1000 cities
# 38 results
# Ocala is 597 out of 1000 cities
# 94 results
# Tinley Park is 598 out of 1000 cities
# 76 results
# Port Orange is 599 out of 1000 cities
# 71 results
# Oak Lawn is 600 out of 1000 cities
# 8 results
# Rocky Mount is 601 out of 1000 cities
# 87 results
# Kokomo is 602 out of 1000 cities
# 21 results
# Coconut Creek is 603 out of 1000 cities
# 26 results
# Bowie is 604 out of 1000 cities
# 3 results
# Berwyn is 605 out of 1000 cities
# 11 results
# Midwest City is 606 out of 1000 cities
# 68 results
# Fountain Valley is 607 out of 1000 cities
# 30 results
# Buckeye is 608 out of 1000 cities
# 85 results
# Dearborn Heights is 609 out of 1000 cities
# 55 results
# Woodland is 610 out of 1000 cities
# 58 results
# Noblesville is 611 out of 1000 cities
# 62 results
# Valdosta is 612 out of 1000 cities
# 2 results
# Diamond Bar is 613 out of 1000 cities
# 10 results
# Manhattan is 614 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 77 results
# Santee is 615 out of 1000 cities
# 60 results
# Taunton is 616 out of 1000 cities
# 89 results
# Sanford is 617 out of 1000 cities
# 7 results
# Kettering is 618 out of 1000 cities
# 73 results
# New Brunswick is 619 out of 1000 cities
# 69 results
# Chicopee is 620 out of 1000 cities
# 70 results
# Anderson is 621 out of 1000 cities
# 56 results
# Margate is 622 out of 1000 cities
# 35 results
# Weymouth Town is 623 out of 1000 cities
# 42 results
# Hempstead is 624 out of 1000 cities
# 7 results
# Corvallis is 625 out of 1000 cities
# 81 results
# Eastvale is 626 out of 1000 cities
# 43 results
# Porterville is 627 out of 1000 cities
# 91 results
# West Haven is 628 out of 1000 cities
# 37 results
# Brentwood is 629 out of 1000 cities
# 39 results
# Paramount is 630 out of 1000 cities
# 16 results
# Grand Forks is 631 out of 1000 cities
# 83 results
# Georgetown is 632 out of 1000 cities
# 89 results
# St. Peters is 633 out of 1000 cities
# 92 results
# Shoreline is 634 out of 1000 cities
# 56 results
# Mount Prospect is 635 out of 1000 cities
# 81 results
# Hanford is 636 out of 1000 cities
# 91 results
# Normal is 637 out of 1000 cities
# 28 results
# Rosemead is 638 out of 1000 cities
# 12 results
# Lehi is 639 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 81 results
# Pocatello is 640 out of 1000 cities
# 53 results
# Highland is 641 out of 1000 cities
# 86 results
# Novato is 642 out of 1000 cities
# 76 results
# Port Arthur is 643 out of 1000 cities
# 81 results
# Carson City is 644 out of 1000 cities
# 35 results
# Hendersonville is 645 out of 1000 cities
# 14 results
# Elyria is 646 out of 1000 cities
# 68 results
# Revere is 647 out of 1000 cities
# 32 results
# Pflugerville is 648 out of 1000 cities
# 30 results
# Greenwood is 649 out of 1000 cities
# 51 results
# Wheaton is 650 out of 1000 cities
# 81 results
# Smyrna is 651 out of 1000 cities
# 32 results
# Sarasota is 652 out of 1000 cities
# 63 results
# Blue Springs is 653 out of 1000 cities
# 63 results
# Colton is 654 out of 1000 cities
# 90 results
# Euless is 655 out of 1000 cities
# 62 results
# Castle Rock is 656 out of 1000 cities
# 85 results
# Cathedral City is 657 out of 1000 cities
# 17 results
# Kingsport is 658 out of 1000 cities
# 11 results
# Lake Havasu City is 659 out of 1000 cities
# 42 results
# Pensacola is 660 out of 1000 cities
# 40 results
# Hoboken is 661 out of 1000 cities
# 9 results
# Yucaipa is 662 out of 1000 cities
# 81 results
# Watsonville is 663 out of 1000 cities
# 51 results
# Richland is 664 out of 1000 cities
# 91 results
# Delano is 665 out of 1000 cities
# Rate limit reached. Sleeping for: 855
# 19 results
# Hoffman Estates is 666 out of 1000 cities
# 68 results
# Florissant is 667 out of 1000 cities
# 1 results
# Placentia is 668 out of 1000 cities
# 11 results
# West New York is 669 out of 1000 cities
# 7 results
# Dublin is 670 out of 1000 cities
# 43 results
# Oak Park is 671 out of 1000 cities
# 16 results
# Peabody is 672 out of 1000 cities
# 32 results
# Perth Amboy is 673 out of 1000 cities
# 13 results
# Battle Creek is 674 out of 1000 cities
# 81 results
# Bradenton is 675 out of 1000 cities
# 65 results
# Gilroy is 676 out of 1000 cities
# 71 results
# Milford is 677 out of 1000 cities
# 44 results
# Ankeny is 678 out of 1000 cities
# 72 results
# La Crosse is 679 out of 1000 cities
# 95 results
# Burlington is 680 out of 1000 cities
# 73 results
# DeSoto is 681 out of 1000 cities
# 63 results
# Harrisonburg is 682 out of 1000 cities
# 50 results
# Minnetonka is 683 out of 1000 cities
# 7 results
# Elkhart is 684 out of 1000 cities
# 79 results
# Glendora is 685 out of 1000 cities
# 16 results
# Southaven is 686 out of 1000 cities
# 42 results
# Joplin is 687 out of 1000 cities
# 79 results
# Enid is 688 out of 1000 cities
# 45 results
# Palm Beach Gardens is 689 out of 1000 cities
# 6 results
# Brookhaven is 690 out of 1000 cities
# 12 results
# Plainfield is 691 out of 1000 cities
# Rate limit reached. Sleeping for: 858
# 64 results
# Grand Island is 692 out of 1000 cities
# 74 results
# Palm Desert is 693 out of 1000 cities
# 18 results
# Huntersville is 694 out of 1000 cities
# 25 results
# Tigard is 695 out of 1000 cities
# 33 results
# Lenexa is 696 out of 1000 cities
# 67 results
# Saginaw is 697 out of 1000 cities
# 84 results
# Kentwood is 698 out of 1000 cities
# 16 results
# Doral is 699 out of 1000 cities
# 10 results
# Grapevine is 700 out of 1000 cities
# 67 results
# Aliso Viejo is 701 out of 1000 cities
# 27 results
# Sammamish is 702 out of 1000 cities
# 50 results
# Casa Grande is 703 out of 1000 cities
# 89 results
# Pinellas Park is 704 out of 1000 cities
# 52 results
# West Sacramento is 705 out of 1000 cities
# 66 results
# Burien is 706 out of 1000 cities
# 53 results
# Commerce City is 707 out of 1000 cities
# 70 results
# Monroe is 708 out of 1000 cities
# 86 results
# Cerritos is 709 out of 1000 cities
# 15 results
# Downers Grove is 710 out of 1000 cities
# 9 results
# Coral Gables is 711 out of 1000 cities
# 8 results
# Wilson is 712 out of 1000 cities
# 83 results
# Niagara Falls is 713 out of 1000 cities
# 75 results
# Poway is 714 out of 1000 cities
# 79 results
# Edina is 715 out of 1000 cities
# 3 results
# Cuyahoga Falls is 716 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 84 results
# Rancho Santa Margarita is 717 out of 1000 cities
# 32 results
# Harrisburg is 718 out of 1000 cities
# 50 results
# Huntington is 719 out of 1000 cities
# 89 results
# La Mirada is 720 out of 1000 cities
# 10 results
# Cypress is 721 out of 1000 cities
# 9 results
# Caldwell is 722 out of 1000 cities
# 81 results
# Logan is 723 out of 1000 cities
# 89 results
# Galveston is 724 out of 1000 cities
# 85 results
# Sheboygan is 725 out of 1000 cities
# 72 results
# Middletown is 726 out of 1000 cities
# 73 results
# Murray is 727 out of 1000 cities
# 36 results
# Parker is 728 out of 1000 cities
# 68 results
# Bedford is 729 out of 1000 cities
# 63 results
# East Lansing is 730 out of 1000 cities
# 68 results
# Methuen is 731 out of 1000 cities
# 51 results
# Covina is 732 out of 1000 cities
# 12 results
# Olympia is 733 out of 1000 cities
# 65 results
# Euclid is 734 out of 1000 cities
# 52 results
# Mishawaka is 735 out of 1000 cities
# 80 results
# Salina is 736 out of 1000 cities
# 70 results
# Azusa is 737 out of 1000 cities
# 12 results
# Chesterfield is 738 out of 1000 cities
# 4 results
# Leesburg is 739 out of 1000 cities
# 62 results
# Dunwoody is 740 out of 1000 cities
# Rate limit reached. Sleeping for: 858
# 19 results
# Hattiesburg is 741 out of 1000 cities
# 68 results
# Bonita Springs is 742 out of 1000 cities
# 0 results
# Portage is 743 out of 1000 cities
# 90 results
# St. Louis Park is 744 out of 1000 cities
# 3 results
# Collierville is 745 out of 1000 cities
# 47 results
# Stillwater is 746 out of 1000 cities
# 66 results
# East Providence is 747 out of 1000 cities
# 88 results
# Wauwatosa is 748 out of 1000 cities
# 27 results
# Mentor is 749 out of 1000 cities
# 61 results
# Ceres is 750 out of 1000 cities
# 58 results
# Cedar Hill is 751 out of 1000 cities
# 62 results
# Binghamton is 752 out of 1000 cities
# 49 results
# Coeur d'Alene is 753 out of 1000 cities
# 67 results
# San Luis Obispo is 754 out of 1000 cities
# 76 results
# Minot is 755 out of 1000 cities
# 77 results
# Palm Springs is 756 out of 1000 cities
# 25 results
# Pine Bluff is 757 out of 1000 cities
# 25 results
# Texas City is 758 out of 1000 cities
# 77 results
# Summerville is 759 out of 1000 cities
# 65 results
# Twin Falls is 760 out of 1000 cities
# 94 results
# Jeffersonville is 761 out of 1000 cities
# 4 results
# San Jacinto is 762 out of 1000 cities
# 72 results
# Altoona is 763 out of 1000 cities
# 86 results
# Beavercreek is 764 out of 1000 cities
# 60 results
# Apopka is 765 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 14 results
# Elmhurst is 766 out of 1000 cities
# 5 results
# Maricopa is 767 out of 1000 cities
# 69 results
# Farmington is 768 out of 1000 cities
# 92 results
# Glenview is 769 out of 1000 cities
# 5 results
# Cleveland Heights is 770 out of 1000 cities
# 45 results
# Draper is 771 out of 1000 cities
# 39 results
# Sierra Vista is 772 out of 1000 cities
# 64 results
# Lacey is 773 out of 1000 cities
# 65 results
# Biloxi is 774 out of 1000 cities
# 18 results
# Strongsville is 775 out of 1000 cities
# 55 results
# Barnstable Town is 776 out of 1000 cities
# 86 results
# Wylie is 777 out of 1000 cities
# 54 results
# Sayreville is 778 out of 1000 cities
# 38 results
# Kannapolis is 779 out of 1000 cities
# 24 results
# Charlottesville is 780 out of 1000 cities
# 20 results
# Littleton is 781 out of 1000 cities
# 74 results
# Titusville is 782 out of 1000 cities
# 75 results
# Hackensack is 783 out of 1000 cities
# 4 results
# Pittsfield is 784 out of 1000 cities
# 66 results
# York is 785 out of 1000 cities
# 83 results
# Lombard is 786 out of 1000 cities
# 5 results
# Attleboro is 787 out of 1000 cities
# 89 results
# DeKalb is 788 out of 1000 cities
# 13 results
# Blacksburg is 789 out of 1000 cities
# 56 results
# Haltom City is 790 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 59 results
# Lompoc is 791 out of 1000 cities
# 69 results
# El Centro is 792 out of 1000 cities
# 88 results
# Danville is 793 out of 1000 cities
# 97 results
# Jefferson City is 794 out of 1000 cities
# 41 results
# Cutler Bay is 795 out of 1000 cities
# 22 results
# Oakland Park is 796 out of 1000 cities
# 13 results
# North Miami Beach is 797 out of 1000 cities
# 26 results
# Freeport is 798 out of 1000 cities
# 16 results
# Moline is 799 out of 1000 cities
# 97 results
# Coachella is 800 out of 1000 cities
# 22 results
# Fort Pierce is 801 out of 1000 cities
# 21 results
# Bountiful is 802 out of 1000 cities
# 44 results
# Fond du Lac is 803 out of 1000 cities
# 27 results
# Keller is 804 out of 1000 cities
# 58 results
# Belleville is 805 out of 1000 cities
# 5 results
# Bell Gardens is 806 out of 1000 cities
# 6 results
# North Lauderdale is 807 out of 1000 cities
# 12 results
# Rancho Palos Verdes is 808 out of 1000 cities
# 5 results
# San Bruno is 809 out of 1000 cities
# 30 results
# Apex is 810 out of 1000 cities
# 49 results
# Altamonte Springs is 811 out of 1000 cities
# 10 results
# Hutchinson is 812 out of 1000 cities
# 11 results
# Buffalo Grove is 813 out of 1000 cities
# 69 results
# Urbandale is 814 out of 1000 cities
# 71 results
# State College is 815 out of 1000 cities
# 81 results
# Urbana is 816 out of 1000 cities
# Rate limit reached. Sleeping for: 860
# 80 results
# Manassas is 817 out of 1000 cities
# 8 results
# Kearny is 818 out of 1000 cities
# 4 results
# Oro Valley is 819 out of 1000 cities
# 63 results
# Findlay is 820 out of 1000 cities
# 80 results
# Rohnert Park is 821 out of 1000 cities
# 96 results
# Westfield is 822 out of 1000 cities
# 64 results
# Linden is 823 out of 1000 cities
# 4 results
# Sumter is 824 out of 1000 cities
# 81 results
# Wilkes-Barre is 825 out of 1000 cities
# 38 results
# Woonsocket is 826 out of 1000 cities
# 89 results
# Leominster is 827 out of 1000 cities
# 87 results
# Shelton is 828 out of 1000 cities
# 49 results
# Brea is 829 out of 1000 cities
# 10 results
# Covington is 830 out of 1000 cities
# 22 results
# Rockwall is 831 out of 1000 cities
# 45 results
# Riverton is 832 out of 1000 cities
# 44 results
# Morgan Hill is 833 out of 1000 cities
# 28 results
# Edmonds is 834 out of 1000 cities
# 42 results
# Burleson is 835 out of 1000 cities
# 66 results
# Beverly is 836 out of 1000 cities
# 13 results
# Mankato is 837 out of 1000 cities
# 72 results
# Hagerstown is 838 out of 1000 cities
# 56 results
# Prescott is 839 out of 1000 cities
# 75 results
# Campbell is 840 out of 1000 cities
# 21 results
# Cedar Falls is 841 out of 1000 cities
# Rate limit reached. Sleeping for: 858
# 74 results
# La Puente is 842 out of 1000 cities
# 14 results
# Crystal Lake is 843 out of 1000 cities
# 83 results
# Fitchburg is 844 out of 1000 cities
# 73 results
# Carol Stream is 845 out of 1000 cities
# 66 results
# Hickory is 846 out of 1000 cities
# 65 results
# Streamwood is 847 out of 1000 cities
# 73 results
# Norwich is 848 out of 1000 cities
# 86 results
# Coppell is 849 out of 1000 cities
# 59 results
# San Gabriel is 850 out of 1000 cities
# 15 results
# Holyoke is 851 out of 1000 cities
# 65 results
# Bentonville is 852 out of 1000 cities
# 84 results
# Florence is 853 out of 1000 cities
# 94 results
# Peachtree Corners is 854 out of 1000 cities
# 22 results
# Bozeman is 855 out of 1000 cities
# 92 results
# New Berlin is 856 out of 1000 cities
# 30 results
# Goose Creek is 857 out of 1000 cities
# 64 results
# Prescott Valley is 858 out of 1000 cities
# 80 results
# Maplewood is 859 out of 1000 cities
# 2 results
# Romeoville is 860 out of 1000 cities
# 66 results
# Duncanville is 861 out of 1000 cities
# 52 results
# Atlantic City is 862 out of 1000 cities
# 59 results
# The Colony is 863 out of 1000 cities
# 62 results
# Culver City is 864 out of 1000 cities
# 12 results
# Marlborough is 865 out of 1000 cities
# 63 results
# Hilton Head Island is 866 out of 1000 cities
# Rate limit reached. Sleeping for: 858
# 74 results
# Moorhead is 867 out of 1000 cities
# 72 results
# Calexico is 868 out of 1000 cities
# 88 results
# Bullhead City is 869 out of 1000 cities
# 95 results
# Germantown is 870 out of 1000 cities
# 50 results
# La Quinta is 871 out of 1000 cities
# 23 results
# Wausau is 872 out of 1000 cities
# 87 results
# Sherman is 873 out of 1000 cities
# 83 results
# Ocoee is 874 out of 1000 cities
# 4 results
# Shakopee is 875 out of 1000 cities
# 4 results
# Woburn is 876 out of 1000 cities
# 26 results
# Bremerton is 877 out of 1000 cities
# 40 results
# Rock Island is 878 out of 1000 cities
# 97 results
# Muskogee is 879 out of 1000 cities
# 56 results
# Cape Girardeau is 880 out of 1000 cities
# 47 results
# Annapolis is 881 out of 1000 cities
# 73 results
# Greenacres is 882 out of 1000 cities
# 1 results
# Ormond Beach is 883 out of 1000 cities
# 67 results
# Hallandale Beach is 884 out of 1000 cities
# 17 results
# Stanton is 885 out of 1000 cities
# 46 results
# Puyallup is 886 out of 1000 cities
# 84 results
# Pacifica is 887 out of 1000 cities
# 23 results
# Hanover Park is 888 out of 1000 cities
# 73 results
# Hurst is 889 out of 1000 cities
# Rate limit reached. Sleeping for: 859
# 51 results
# Lima is 890 out of 1000 cities
# 61 results
# Marana is 891 out of 1000 cities
# 67 results
# Carpentersville is 892 out of 1000 cities
# 68 results
# Oakley is 893 out of 1000 cities
# 91 results
# Huber Heights is 894 out of 1000 cities
# 55 results
# Montclair is 895 out of 1000 cities
# 64 results
# Wheeling is 896 out of 1000 cities
# 71 results
# Brookfield is 897 out of 1000 cities
# 30 results
# Park Ridge is 898 out of 1000 cities
# 13 results
# Roy is 899 out of 1000 cities
# 89 results
# Winter Garden is 900 out of 1000 cities
# 5 results
# Chelsea is 901 out of 1000 cities
# 28 results
# Valley Stream is 902 out of 1000 cities
# 3 results
# Spartanburg is 903 out of 1000 cities
# 81 results
# Lake Oswego is 904 out of 1000 cities
# 34 results
# Friendswood is 905 out of 1000 cities
# 41 results
# Westerville is 906 out of 1000 cities
# 22 results
# Northglenn is 907 out of 1000 cities
# 69 results
# Phenix City is 908 out of 1000 cities
# 66 results
# Grove City is 909 out of 1000 cities
# 19 results
# Texarkana is 910 out of 1000 cities
# 41 results
# Addison is 911 out of 1000 cities
# 12 results
# Dover is 912 out of 1000 cities
# 97 results
# Lincoln Park is 913 out of 1000 cities
# 58 results
# Calumet City is 914 out of 1000 cities
# Rate limit reached. Sleeping for: 862
# 12 results
# Muskegon is 915 out of 1000 cities
# 63 results
# Aventura is 916 out of 1000 cities
# 10 results
# Martinez is 917 out of 1000 cities
# 60 results
# Greenfield is 918 out of 1000 cities
# 30 results
# Apache Junction is 919 out of 1000 cities
# 55 results
# Monrovia is 920 out of 1000 cities
# 15 results
# Weslaco is 921 out of 1000 cities
# 80 results
# Keizer is 922 out of 1000 cities
# 69 results
# Spanish Fork is 923 out of 1000 cities
# 91 results
# Beloit is 924 out of 1000 cities
# 49 results
# Panama City is 925 out of 1000 cities
# 23 results
# {'limit': 180, 'remaining': 103, 'reset': 1523858664}
# reset time: 2018-04-15 23:04:24

# %%
import pandas as pd
import numpy as np
import plotly.plotly
df = pd.read_csv('output/Trump_1000_Cities_CSV.csv')     #Just put your output file here the rest should run
#print(df.head())
df.reset_index()

avgsent = df.groupby(['location'], as_index=True).agg(                             #get the mean sentiment for each city
                      {'tweet sentiment':['mean']})
avgcount = df.groupby(['location'], as_index=True).agg(                          #get a count of how many tweets there are for circle size
                      {'tweet sentiment':['count']})

lat = df.groupby(['location'], as_index=True)['location', 'lat'].head(1)         # get the lat this took like two hours fuck you pandas
lat1 = lat.set_index(['location'])

long = df.groupby(['location'], as_index=True)['location', 'long'].head(1)     #same for long
long1 = long.set_index(['location'])

formap = pd.concat([avgsent, avgcount, lat1, long1], axis=1)
latlong = pd.concat([lat1, long1],axis=1,)

formap                                  #this is the cleaned df for the map                     
formap = formap.rename( columns={"(tweet sentiment, mean)": "avg sentiment", "(tweet sentiment, count)": "count"})
formap = formap.reset_index()
formap.columns = ['city', 'mean sentiment', 'count', 'lat', 'long']
formap['mean sentiment'] = formap['mean sentiment'].apply(lambda x: x*100) #make the mean sentiment go from -100 to 100
formap.shape
formap.head()
# Out:
#       city  mean sentiment  count         lat         long
# 0  Abilene        6.912623     61  32.4487364  -99.7331439
# 1  Addison       -6.135000     12  41.931696,  87.9889556,
# 2    Akron       -3.189000     80  41.0814447  -81.5190052
# 3  Alameda        2.550256     39  37.7652065  -122.241635
# 4   Albany       -9.779375     80  44.6365107  -123.105928

# %%
#Everything should be good to go here just change the title

formap['text'] = formap['city'] + '<br>Mean Sentiment: ' + (formap['mean sentiment']).astype(str) + '<br>Tweet Count: ' + (formap['count']).astype(str)
limits = [(0,10000)]
cities = []


for i in range(len(limits)):
    
    lim = limits[i]
    formap_sub = formap[lim[0]:lim[1]]  
    city = dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = formap_sub['long'],         
        lat = formap_sub['lat'],
        text=formap_sub['text'],
        mode='markers',
        marker = dict(
            size = formap_sub['count'] * 2,
            opacity = .7,
            color = formap_sub['mean sentiment'],
            colorscale='Blackbody',
            showscale=True, 
            reversescale = False,
            colorbar= dict(title = 'Sentiment Score <br>(100 = Positive) <br>(-100 = Negative)', titleseide = 'top'),
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
    )       
    cities.append(city)

layout = dict(
        title = 'Trump Sentiment (by 1000 Cities)',             #change the title here. 
        showlegend = False,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
            
        ),
    )

fig = dict( data=cities, layout=layout )
plotly.offline.plot( fig, validate=False, filename='d3-bubble-map-populations.html' )
# Out:
# 'file://C:\\Users\\Steve\\Dropbox\\Dow\\03-Steve\\02-Personal\\03-Education\\03-UCSD\\2018-01-Data-Science\\Dow-Projects\\Sentiment-Search-Engine\\d3-bubble-map-populations.html'
